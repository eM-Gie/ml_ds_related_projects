# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x +p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M3 = np.vstack( (np.ones_like(x), x, x**2, x**3) ).T
p3 = np.linalg.lstsq(M3, y, rcond=None)

f_lr_3 = lambda x: p3[0][3]* x**3 + p3[0][2]*pow(x,2) + p3[0][1] * x + p3[0][0] 

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_3(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M4 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4) ).T
p4 = np.linalg.lstsq(M4, y, rcond=None)

f_lr_4 = lambda x: p4[0][4]*x**4 + p4[0][3]* x**3 + p4[0][2]*pow(x,2) + p4[0][1] * x + p4[0][0] 

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_4(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4, x**5) ).T
p5 = np.linalg.lstsq(M5, y, rcond=None)

f_lr_5 = lambda x: p5[0][5]*x**5 + p5[0][4]*x**4 + p5[0][3]* x**3 + p5[0][2]*pow(x,2) + p5[0][1] * x + p5[0][0] 

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_5(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %%
x_f_lr = np.linspace(0., 3, 200)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, f_lr_1(x_tr), 'g');
plt.plot(x_f_lr, f_lr_2(x_tr), 'b');
plt.plot(x_f_lr, f_lr_3(x_tr), 'y');
plt.plot(x_f_lr, f_lr_4(x_tr), 'r');
plt.plot(x_f_lr, f_lr_5(x_tr), 'g');

plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()

# %%
print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.486
# Dependent Variable: y                AIC:                634.8442
# Date:               2023-04-14 14:52 BIC:                640.0546
# No. Observations:   100              Log-Likelihood:     -315.42
# Df Model:           1                F-statistic:        94.62
# Df Residuals:       98               Prob (F-statistic): 4.73e-16
# R-squared:          0.491            Scale:              32.811
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -3.0232     1.0874   -2.7802   0.0065   -5.1812   -0.8653
# x1         6.6088     0.6794    9.7273   0.0000    5.2606    7.9571
# -----------------------------------------------------------------
# Omnibus:              15.797       Durbin-Watson:          2.261
# Prob(Omnibus):        0.000        Jarque-Bera (JB):       18.088
# Skew:                 0.903        Prob(JB):               0.000
# Kurtosis:             4.038        Condition No.:          4
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.803
# Dependent Variable: y                AIC:                539.7397
# Date:               2023-04-14 14:52 BIC:                547.5552
# No. Observations:   100              Log-Likelihood:     -266.87
# Df Model:           2                F-statistic:        203.2
# Df Residuals:       97               Prob (F-statistic): 2.06e-35
# R-squared:          0.807            Scale:              12.553
# -------------------------------------------------------------------
#          Coef.     Std.Err.      t      P>|t|     [0.025     0.975]
# -------------------------------------------------------------------
# const     6.7101     1.0236    6.5556   0.0000     4.6786    8.7415
# x1      -13.1570     1.6222   -8.1107   0.0000   -16.3766   -9.9374
# x2        6.6977     0.5309   12.6154   0.0000     5.6440    7.7514
# -----------------------------------------------------------------
# Omnibus:               17.043       Durbin-Watson:          2.218
# Prob(Omnibus):         0.000        Jarque-Bera (JB):       4.592
# Skew:                  -0.043       Prob(JB):               0.101
# Kurtosis:              1.954        Condition No.:          22
# =================================================================

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy izusklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()

# %%
print(Res1F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.491
# Model:                            OLS   Adj. R-squared:                  0.486
# Method:                 Least Squares   F-statistic:                     94.62
# Date:                Fri, 14 Apr 2023   Prob (F-statistic):           4.73e-16
# Time:                        14:55:45   Log-Likelihood:                -315.42
# No. Observations:                 100   AIC:                             634.8
# Df Residuals:                      98   BIC:                             640.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.0232      1.087     -2.780      0.007      -5.181      -0.865
# x              6.6088      0.679      9.727      0.000       5.261       7.957
# ==============================================================================
# Omnibus:                       15.797   Durbin-Watson:                   2.261
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.088
# Skew:                           0.903   Prob(JB):                     0.000118
# Kurtosis:                       4.038   Cond. No.                         3.97
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.807
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     203.2
# Date:                Fri, 14 Apr 2023   Prob (F-statistic):           2.06e-35
# Time:                        14:55:45   Log-Likelihood:                -266.87
# No. Observations:                 100   AIC:                             539.7
# Df Residuals:                      97   BIC:                             547.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.7101      1.024      6.556      0.000       4.679       8.742
# x            -13.1570      1.622     -8.111      0.000     -16.377      -9.937
# I(x ** 2)      6.6977      0.531     12.615      0.000       5.644       7.751
# ==============================================================================
# Omnibus:                       17.043   Durbin-Watson:                   2.218
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                4.592
# Skew:                          -0.043   Prob(JB):                        0.101
# Kurtosis:                       1.954   Cond. No.                         21.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
