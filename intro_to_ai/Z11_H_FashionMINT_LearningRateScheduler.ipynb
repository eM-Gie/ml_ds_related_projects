# %%
import tensorflow as tf
from tensorflow import keras
from keras.callbacks import LearningRateScheduler
from keras.models import Sequential
from keras.layers import Dense

from keras.callbacks import History

print(tf.__version__)

print(keras.__version__)
# Out:
# 2.11.0
# 2.11.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()

# %%
X_train_full.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# Each pixel intensity is represented as a byte (0 to 255):

# %%
X_train_full.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# * Podzielmy pełny zestaw treningowy na zestaw walidacyjny i zestaw treningowy.
# * Kolor pikseli skalujemy również do zakresu 0-1 i przekształcamy na zmiennoprzecinkowe, dzieląc przez 255.

# %%
X_valid, X_train = X_train_full[:5000] / 255., X_train_full[5000:] / 255.
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test / 255.

# %%
plt.imshow(X_train[0], cmap="binary")
plt.axis('off')
plt.show()

# %%
y_train
# Out:
# array([4, 0, 7, ..., 3, 0, 5], dtype=uint8)

# %% [markdown]
# Będziemy używać klas numerycznych i nazw.

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

class_names[y_train[0]]
# Out:
# 'Coat'

# %% [markdown]
# Możemy narysować więcej przykładów treningowych.

# %%
n_rows = 4
n_cols = 10
plt.figure(figsize=(n_cols * 1.2, n_rows * 1.2))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train[index], cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(class_names[y_train[index]], fontsize=12)
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %% [markdown]
# # Zad
#
# Wykonaj analogiczne zadanie dla
# * Adam bez LearningRateScheduler i learning_rate=0.001
# * Adam z użyciem LearningRateScheduler i learning_rate=0.001
# * Adam z użyciem LearningRateScheduler i learning_rate=0.0001
#
# Zwizualizuj wyniki:
#
# * porównaj krzywe uczenia

# %%
keras.backend.clear_session()
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)


history_Adam = History()

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])

model.summary()

Adam = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)

model.compile(loss="sparse_categorical_crossentropy", optimizer=Adam, metrics=["accuracy"])

model.fit(X_train, y_train, validation_data= (X_test, y_test), batch_size=32,epochs=10, callbacks=[ history_Adam])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 300)               235500
#
#  dense_1 (Dense)             (None, 100)               30100
#
#  dense_2 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.4837 - accuracy: 0.8246 - val_loss: 0.4110 - val_accuracy: 0.8488
# Epoch 2/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3630 - accuracy: 0.8677 - val_loss: 0.4220 - val_accuracy: 0.8463
# Epoch 3/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3309 - accuracy: 0.8763 - val_loss: 0.3620 - val_accuracy: 0.8734
# Epoch 4/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3039 - accuracy: 0.8867 - val_loss: 0.3670 - val_accuracy: 0.8703
# Epoch 5/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2868 - accuracy: 0.8924 - val_loss: 0.3364 - val_accuracy: 0.8753
# Epoch 6/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2717 - accuracy: 0.8993 - val_loss: 0.3439 - val_accuracy: 0.8798
# Epoch 7/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2598 - accuracy: 0.9035 - val_loss: 0.3455 - val_accuracy: 0.8798
# Epoch 8/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2474 - accuracy: 0.9062 - val_loss: 0.3360 - val_accuracy: 0.8821
# Epoch 9/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2377 - accuracy: 0.9101 - val_loss: 0.3329 - val_accuracy: 0.8830
# Epoch 10/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2263 - accuracy: 0.9135 - val_loss: 0.3517 - val_accuracy: 0.8860

# %%
keras.backend.clear_session()

def step_decay(epoch):
    initial_lrate = 0.01
    drop = 0.5
    epochs_drop = 10.0
    lrate = initial_lrate * np.power(drop, np.floor((1+epoch)/epochs_drop))
    return lrate


history_adam_lr_1 = History()


model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])

model.summary()

Adam = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)

model.compile(loss="sparse_categorical_crossentropy", optimizer=Adam, metrics=["accuracy"])

lrate = LearningRateScheduler(step_decay)
model.fit(X_train, y_train, validation_data= (X_test, y_test), batch_size=32,epochs=10, callbacks=[lrate, history_adam_lr_1])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 300)               235500
#
#  dense_1 (Dense)             (None, 100)               30100
#
#  dense_2 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.5580 - accuracy: 0.8025 - val_loss: 0.5269 - val_accuracy: 0.8278 - lr: 0.0100
# Epoch 2/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4420 - accuracy: 0.8415 - val_loss: 0.4932 - val_accuracy: 0.8312 - lr: 0.0100
# Epoch 3/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4165 - accuracy: 0.8518 - val_loss: 0.4589 - val_accuracy: 0.8338 - lr: 0.0100
# Epoch 4/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4027 - accuracy: 0.8553 - val_loss: 0.4638 - val_accuracy: 0.8483 - lr: 0.0100
# Epoch 5/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3991 - accuracy: 0.8591 - val_loss: 0.4427 - val_accuracy: 0.8474 - lr: 0.0100
# Epoch 6/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3876 - accuracy: 0.8608 - val_loss: 0.4342 - val_accuracy: 0.8515 - lr: 0.0100
# Epoch 7/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3895 - accuracy: 0.8637 - val_loss: 0.5070 - val_accuracy: 0.8339 - lr: 0.0100
# Epoch 8/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3743 - accuracy: 0.8679 - val_loss: 0.4271 - val_accuracy: 0.8480 - lr: 0.0100
# Epoch 9/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3668 - accuracy: 0.8699 - val_loss: 0.4427 - val_accuracy: 0.8548 - lr: 0.0100
# Epoch 10/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3170 - accuracy: 0.8856 - val_loss: 0.3870 - val_accuracy: 0.8690 - lr: 0.0050

# %%
keras.backend.clear_session()

history_adam_lr_2 = History()


model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])

model.summary()

Adam2 = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)

model.compile(loss="sparse_categorical_crossentropy", optimizer=Adam2, metrics=["accuracy"])

lrate = LearningRateScheduler(step_decay)
model.fit(X_train, y_train, validation_data= (X_test, y_test), batch_size=32,epochs=10, callbacks=[lrate, history_adam_lr_2])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 300)               235500
#
#  dense_1 (Dense)             (None, 100)               30100
#
#  dense_2 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.5539 - accuracy: 0.8041 - val_loss: 0.5229 - val_accuracy: 0.8229 - lr: 0.0100
# Epoch 2/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4472 - accuracy: 0.8423 - val_loss: 0.5367 - val_accuracy: 0.8211 - lr: 0.0100
# Epoch 3/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4217 - accuracy: 0.8504 - val_loss: 0.4413 - val_accuracy: 0.8414 - lr: 0.0100
# Epoch 4/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4059 - accuracy: 0.8547 - val_loss: 0.4347 - val_accuracy: 0.8512 - lr: 0.0100
# Epoch 5/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3919 - accuracy: 0.8619 - val_loss: 0.4253 - val_accuracy: 0.8513 - lr: 0.0100
# Epoch 6/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3897 - accuracy: 0.8622 - val_loss: 0.4353 - val_accuracy: 0.8489 - lr: 0.0100
# Epoch 7/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3824 - accuracy: 0.8658 - val_loss: 0.4469 - val_accuracy: 0.8480 - lr: 0.0100
# Epoch 8/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3778 - accuracy: 0.8681 - val_loss: 0.4378 - val_accuracy: 0.8440 - lr: 0.0100
# Epoch 9/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3705 - accuracy: 0.8692 - val_loss: 0.4620 - val_accuracy: 0.8520 - lr: 0.0100
# Epoch 10/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3218 - accuracy: 0.8818 - val_loss: 0.3963 - val_accuracy: 0.8615 - lr: 0.0050

# %%
import matplotlib.pyplot as pl
plt.plot(history_Adam.history['accuracy'], label = "tarina no_lr")
plt.plot(history_Adam.history['val_accuracy'], label = "test no_lr")
plt.plot(history_adam_lr_1.history['accuracy'], label = "tarina lr_1")
plt.plot(history_adam_lr_1.history['val_accuracy'], label = "test lr_1")
plt.plot(history_adam_lr_2.history['accuracy'], label = "tarina lr_2")
plt.plot(history_adam_lr_2.history['val_accuracy'], label = "test lr_2")

plt.legend()
plt.show()
